# %% [markdown]
# <a href="https://colab.research.google.com/github/Harmokay/my-python-learning-journey/blob/main/Workshop_3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tasks

# %% [markdown]
# ## P 3.1: Download the CarSharing dataset from Canvas and apply the normal linear regression and the Ridge regression methods to predict the 'demand' column. Use 5 different values for the regularisation parameter in the Ridge regression and repeat the prediction. Calculate all evaluation metrics discussed in the lecture session for both models and all repetitions and print them. Interpret the results and report your interpretation in the report cell (completing the report cell is required) (15%)

# %%
############# WRITE YOUR CODE IN THIS CELL (IF APPLICABLE)  ####################
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fc956100-8b5c-434c-9264-67aaf9918bf2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc956100-8b5c-434c-9264-67aaf9918bf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('CarSharing (1).csv')

# %%
data.head()
# Out:
#    id            timestamp  season holiday workingday                 weather  \
# 0   1  2017-01-01 00:00:00  spring      No         No  Clear or partly cloudy
# 1   2  2017-01-01 01:00:00  spring      No         No  Clear or partly cloudy
# 2   3  2017-01-01 02:00:00  spring      No         No  Clear or partly cloudy
# 3   4  2017-01-01 03:00:00  spring      No         No  Clear or partly cloudy
# 4   5  2017-01-01 04:00:00  spring      No         No  Clear or partly cloudy
#
#    temp  temp_feel  humidity  windspeed    demand
# 0  9.84     14.395      81.0        0.0  2.772589
# 1  9.02     13.635      80.0        0.0  3.688879
# 2  9.02     13.635      80.0        0.0  3.465736
# 3  9.84     14.395      75.0        0.0  2.564949
# 4  9.84     14.395      75.0        0.0  0.000000

# %%
data.shape
# Out:
# (8708, 11)

# %%
#reindexing
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#         id            timestamp  season holiday workingday  \
# 0        1  2017-01-01 00:00:00  spring      No         No
# 1        2  2017-01-01 01:00:00  spring      No         No
# 2        3  2017-01-01 02:00:00  spring      No         No
# 3        4  2017-01-01 03:00:00  spring      No         No
# 4        5  2017-01-01 04:00:00  spring      No         No
# ...    ...                  ...     ...     ...        ...
# 8703  8704  2018-08-05 00:00:00    fall      No         No
# 8704  8705  2018-08-05 01:00:00    fall      No         No
# 8705  8706  2018-08-05 02:00:00    fall      No         No
# 8706  8707  2018-08-05 03:00:00    fall      No         No
# 8707  8708  2018-08-05 04:00:00    fall      No         No
#
#                      weather   temp  temp_feel  humidity  windspeed    demand
# 0     Clear or partly cloudy   9.84     14.395      81.0     0.0000  2.772589
# 1     Clear or partly cloudy   9.02     13.635      80.0     0.0000  3.688879
# ...

# %%
#creating new dataset
data_new = data.sample(n=5000, random_state = 48)
print(data_new)
# Out:
#         id            timestamp  season holiday workingday  \
# 446    447  2017-02-01 16:00:00  spring      No        Yes
# 549    550  2017-02-06 01:00:00  spring      No         No
# 3612  3613  2017-09-01 10:00:00    fall      No        Yes
# 6659  6660  2018-03-14 18:00:00  spring      No        Yes
# 7518  7519  2018-05-12 15:00:00  summer      No         No
# ...    ...                  ...     ...     ...        ...
# 8373  8374  2018-07-10 06:00:00    fall      No        Yes
# 7195  7196  2018-04-18 04:00:00  summer      No        Yes
# 2535  2536  2017-06-13 13:00:00  summer      No        Yes
# 6456  6457  2018-03-06 06:00:00  spring      No        Yes
# 8122  8123  2018-06-18 19:00:00  summer      No        Yes
#
#                      weather   temp  temp_feel  humidity  windspeed    demand
# 446                     Mist   9.84     12.120      75.0     8.9981  4.158883
# 549   Clear or partly cloudy  10.66     11.365      65.0    27.9993  3.784190
# ...

# %%
#reindexing the new dataset
data_new.reset_index(drop=True, inplace=True)

# %%
data_new
# Out:
#         id            timestamp  season holiday workingday  \
# 0      447  2017-02-01 16:00:00  spring      No        Yes
# 1      550  2017-02-06 01:00:00  spring      No         No
# 2     3613  2017-09-01 10:00:00    fall      No        Yes
# 3     6660  2018-03-14 18:00:00  spring      No        Yes
# 4     7519  2018-05-12 15:00:00  summer      No         No
# ...    ...                  ...     ...     ...        ...
# 4995  8374  2018-07-10 06:00:00    fall      No        Yes
# 4996  7196  2018-04-18 04:00:00  summer      No        Yes
# 4997  2536  2017-06-13 13:00:00  summer      No        Yes
# 4998  6457  2018-03-06 06:00:00  spring      No        Yes
# 4999  8123  2018-06-18 19:00:00  summer      No        Yes
#
#                      weather   temp  temp_feel  humidity  windspeed    demand
# 0                       Mist   9.84     12.120      75.0     8.9981  4.158883
# 1     Clear or partly cloudy  10.66     11.365      65.0    27.9993  3.784190
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8708 entries, 0 to 8707
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          8708 non-null   int64
#  1   timestamp   8708 non-null   object
#  2   season      8708 non-null   object
#  3   holiday     8708 non-null   object
#  4   workingday  8708 non-null   object
#  5   weather     8708 non-null   object
#  6   temp        7506 non-null   float64
#  7   temp_feel   8606 non-null   float64
#  8   humidity    8669 non-null   float64
#  9   windspeed   8508 non-null   float64
#  10  demand      8708 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 748.5+ KB

# %%
#Getting statistical information of the dataset for different columns (features)
data.describe(include='all')
# Out:
#                  id            timestamp  season holiday workingday  \
# count   8708.000000                 8708    8708    8708       8708
# unique          NaN                 8708       4       2          2
# top             NaN  2018-08-05 04:00:00  summer      No        Yes
# freq            NaN                    1    2733    8469       5949
# mean    4354.500000                  NaN     NaN     NaN        NaN
# std     2513.927405                  NaN     NaN     NaN        NaN
# min        1.000000                  NaN     NaN     NaN        NaN
# 25%     2177.750000                  NaN     NaN     NaN        NaN
# 50%     4354.500000                  NaN     NaN     NaN        NaN
# 75%     6531.250000                  NaN     NaN     NaN        NaN
# max     8708.000000                  NaN     NaN     NaN        NaN
#
#                        weather         temp    temp_feel    humidity  \
# count                     8708  7506.000000  8606.000000  8669.00000
# ...

# %%
#dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8708 entries, 0 to 8707
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          8708 non-null   int64
#  1   timestamp   8708 non-null   object
#  2   season      8708 non-null   object
#  3   holiday     8708 non-null   object
#  4   workingday  8708 non-null   object
#  5   weather     8708 non-null   object
#  6   temp        7506 non-null   float64
#  7   temp_feel   8606 non-null   float64
#  8   humidity    8669 non-null   float64
#  9   windspeed   8508 non-null   float64
#  10  demand      8708 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 748.5+ KB

# %%
#drop a column
data.drop( ['temp_feel', 'timestamp'], axis=1)
# Out:
#         id  season holiday workingday                 weather   temp  \
# 0        1  spring      No         No  Clear or partly cloudy   9.84
# 1        2  spring      No         No  Clear or partly cloudy   9.02
# 2        3  spring      No         No  Clear or partly cloudy   9.02
# 3        4  spring      No         No  Clear or partly cloudy   9.84
# 4        5  spring      No         No  Clear or partly cloudy   9.84
# ...    ...     ...     ...        ...                     ...    ...
# 8703  8704    fall      No         No  Clear or partly cloudy  30.34
# 8704  8705    fall      No         No  Clear or partly cloudy  30.34
# 8705  8706    fall      No         No  Clear or partly cloudy  30.34
# 8706  8707    fall      No         No  Clear or partly cloudy  29.52
# 8707  8708    fall      No         No  Clear or partly cloudy  29.52
#
#       humidity  windspeed    demand
# 0         81.0     0.0000  2.772589
# 1         80.0     0.0000  3.688879
# ...

# %%
#numerical columns
num_cols= data.select_dtypes(include=['int64', 'float64']).columns
print(num_cols)
# Out:
# Index(['id', 'temp', 'temp_feel', 'humidity', 'windspeed', 'demand'], dtype='object')

# %%
#categorical columns
cat_cols= data.select_dtypes(include=['object']).columns
print(cat_cols)
# Out:
# Index(['timestamp', 'season', 'holiday', 'workingday', 'weather'], dtype='object')

# %%
#encoding the categorical columns
data_encoded= pd.get_dummies(data, columns=cat_cols, drop_first=True)

# %%
print(data_encoded.head())
# Out:
#    id  temp  temp_feel  humidity  windspeed    demand  \
# 0   1  9.84     14.395      81.0        0.0  2.772589
# 1   2  9.02     13.635      80.0        0.0  3.688879
# 2   3  9.02     13.635      80.0        0.0  3.465736
# 3   4  9.84     14.395      75.0        0.0  2.564949
# 4   5  9.84     14.395      75.0        0.0  0.000000
#
#    timestamp_2017-01-01 01:00:00  timestamp_2017-01-01 02:00:00  \
# 0                          False                          False
# 1                           True                          False
# 2                          False                           True
# 3                          False                          False
# 4                          False                          False
#
#    timestamp_2017-01-01 03:00:00  timestamp_2017-01-01 04:00:00  ...  \
# 0                          False                          False  ...
# 1                          False                          False  ...
# ...

# %%
print(data_encoded.columns)
# Out:
# Index(['id', 'temp', 'temp_feel', 'humidity', 'windspeed', 'demand',
#        'timestamp_2017-01-01 01:00:00', 'timestamp_2017-01-01 02:00:00',
#        'timestamp_2017-01-01 03:00:00', 'timestamp_2017-01-01 04:00:00',
#        ...
#        'timestamp_2018-08-05 03:00:00', 'timestamp_2018-08-05 04:00:00',
#        'season_spring', 'season_summer', 'season_winter', 'holiday_Yes',
#        'workingday_Yes', 'weather_Light snow or rain', 'weather_Mist',
#        'weather_heavy rain/ice pellets/snow + fog'],
#       dtype='object', length=7198)

# %%
#normalize the numerical columns
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
data_encoded[num_cols]= scaler.fit_transform(data_encoded[num_cols])

# %%
print(data_encoded[num_cols].describe())
# Out:
#                 id         temp    temp_feel     humidity    windspeed  \
# count  7185.000000  7185.000000  7185.000000  7185.000000  7185.000000
# mean      0.501513     0.480215     0.510104     0.608440     0.228617
# std       0.289520     0.199952     0.195553     0.196389     0.146283
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.250948     0.326531     0.338964     0.460000     0.122840
# 50%       0.502699     0.489796     0.525338     0.600000     0.228047
# 75%       0.752153     0.632653     0.677928     0.770000     0.333373
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             demand
# count  7185.000000
# mean      0.655634
# std       0.220800
# min       0.000000
# 25%       0.535542
# 50%       0.716621
# 75%       0.818102
# max       1.000000

# %%
print(data_encoded)
# Out:
#             id      temp  temp_feel  humidity  windspeed    demand  \
# 0     0.000000  0.224490   0.305068      0.81   0.000000  0.408193
# 1     0.000115  0.204082   0.288064      0.80   0.000000  0.543094
# 2     0.000230  0.204082   0.288064      0.80   0.000000  0.510241
# 3     0.000345  0.224490   0.305068      0.75   0.000000  0.377624
# 4     0.000459  0.224490   0.305068      0.75   0.000000  0.000000
# ...        ...       ...        ...       ...        ...       ...
# 8703  0.999541  0.734694   0.762725      0.70   0.333373  0.740604
# 8704  0.999655  0.734694   0.762725      0.70   0.298225  0.657491
# 8705  0.999770  0.734694   0.762725      0.70   0.350888  0.631661
# 8706  0.999885  0.714286   0.762725      0.74   0.298225  0.546729
# 8707  1.000000  0.714286   0.762725      0.74   0.298225  0.388534
#
#       timestamp_2017-01-01 01:00:00  timestamp_2017-01-01 02:00:00  \
# 0                             False                          False
# ...

# %%
#import and prepare my data
X= data_encoded.drop('demand', axis=1)
Y= data_encoded['demand']

# %%
#split into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X_train.isnull().sum().sort_values(ascending=False))
# Out:
# weather_heavy rain/ice pellets/snow + fog    0
# id                                           0
# temp                                         0
# temp_feel                                    0
# humidity                                     0
#                                             ..
# timestamp_2017-01-01 14:00:00                0
# timestamp_2017-01-01 13:00:00                0
# timestamp_2017-01-01 12:00:00                0
# timestamp_2017-01-01 11:00:00                0
# timestamp_2017-01-01 10:00:00                0
# Length: 7197, dtype: int64

# %%
print(y_train.isnull().sum())
# Out:
# 0

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
X_columns = X.columns
X_index = y_train.index  # This is the correct index to align with

# %%
X_train = pd.DataFrame(X_train, columns=X_columns, index=X_index)
X_test = pd.DataFrame(X_test, columns=X_columns)

# %%
X_train = pd.DataFrame(X_train, columns=X.columns, index=y_train.index)
X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_train.index.equals(y_train.index))  # Should return True
# Out:
# (5748, 7197)
# (5748,)
# True

# %%
#Training the model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred_lr = lr_model.predict(X_test)

print("Linear Regression:")
# Out:
# Linear Regression:

# %% [raw]
# ############ WRITE YOUR REPORT IN THIS CELL (IF APPLICABLE) #############
